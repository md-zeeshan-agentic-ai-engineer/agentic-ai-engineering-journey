# %% [markdown]
# # decision trees fundamentals

# %%
import pandas as pd

data = {
    "Income": [20, 25, 30, 60, 70, 80],
    "Age": [21, 25, 28, 32, 35, 40],
    "Purchased": [0, 0, 0, 1, 1, 1]
}

df = pd.DataFrame(data)

print(data)
